# %% [markdown]
# # このページについて
# 学んだ性質や定理などをまとめます．散乱しがちな性質の発見はまとめることで意味を成します．
#
# | 学び気づき                                                                                                           | どこで知ったか，内容                                                                                         | 備考                                                                                                                                                   |
# | --------------------------------------------------------------------------------------------------------------- | -------------------------------------------------------------------------------------------------- | ---------------------------------------------------------------------------------------------------------------------------------------------------- |
# | max関数は非滑か                                                                                                       | エピグラフ定式化のチュートリアル論文                                                                                 | RMDPの目的関数は非滑らか                                                                                                                                       |
# | エピグラフは$\alpha$だけ最適化すればよい．                                                                                       | エピグラフ定式化のチュートリアル論文                                                                                 | $\alpha$は関数値とほぼ同じ意味を持つから．                                                                                                                            |
# | エピグラフ定式化，最適解の$\alpha$は必ず関数上にいる．                                                                                 | エピグラフ定式化のチュートリアル論文                                                                                 |                                                                                                                                                      |
# | エピグラフ問題と元の問題は等価である．つまり最適解が一致する．                                                                                 | エピグラフ定式化のチュートリアル論文                                                                                 |                                                                                                                                                      |
# | 元問題とエピグラフが一致するのは，最適性条件として$\alpha$に対する局所性が必要ないから                                                                 | エピグラフ定式化のチュートリアル論文                                                                                 |                                                                                                                                                      |
# | 内積の大きさを上から評価したい場合は，コーシーシュワルツの不等式を使おう．$\|\langle x, y\rangle\| \leq\|x\|\|y\|$<br>                               | 確率的射影勾配法を用いた場合の停留点への収束性を証明する際に，内積を評価する必要があった．                                                      |                                                                                                                                                      |
# | 弱凸関数を解析する場合，弱凸関数の不等式はとても役に立つ．$$ \varphi(y) \ge \varphi(x) + \langle v, y-x \rangle - \frac{\rho}{2}\|y-x\|^2 $$ | 確率的射影勾配法における停留点収束性の証明をするときの出発点                                                                     |                                                                                                                                                      |
# | $f(x)$がC-smoothならC-weakly convexになる．                                                                            | 隠れ凸性の論文                                                                                            |                                                                                                                                                      |
# | ヘルダー連続はリプシッツ連続の一般化                                                                                              | 熱方程式と方策勾配                                                                                          |                                                                                                                                                      |
# | リプシッツ連続なら，almost everywhereでフレシェ微分可能（ラデマッハの定理）                                                                  | 熱方程式と方策勾配                                                                                          |                                                                                                                                                      |
# | 期待値保証からPAC保証に転換可能                                                                                               | 論文                                                                                                 |                                                                                                                                                      |
# | 劣勾配は凸関数に対してのみとれる                                                                                                | GPT                                                                                                |                                                                                                                                                      |
# | 劣勾配法は降下性がない                                                                                                     | 隠れ凸の論文                                                                                             |                                                                                                                                                      |
# | Moreau Envelopeによる平滑化                                                                                           | 非平滑な関数の最適化を解析したいが、微分の概念が使えず困っている場合に用いる。微分可能な代理関数を介して解析を進めるための武器。                                   | $\Delta_{b_0}(\pi)$ はmax関数を含むため非平滑。これを直接扱わず、Moreau Envelope $\Delta_{b_0, \lambda}(\pi)$ の期待減少量を評価することで、確率的方策勾配の収束解析の出発点とした。                         |
# | イェンセンの不等式: $\mathbb{E}[f(X)] \ge f(\mathbb{E}[X])$                                                              | 期待値と非線形関数の順序を交換したい。特に、勾配ノルムの期待値を評価する際に頻出。($\mathbb{E}[\|g\|] \le \sqrt{\mathbb{E}[\|g\|^2]}$)      | 定理1の証明で、$\mathbb{E}[\|\nabla \Delta_{b_0, \lambda}\|]$ を $\sqrt{\mathbb{E}[\|\nabla \Delta_{b_0, \lambda}\|^2]}$ で上から抑え、二乗ノルムの収束レートを実際の最適化ギャップに変換した。 |
# | Tower Property: $\mathbb{E}[X] = \mathbb{E}[\mathbb{E}[X\|\mathcal{F}_t]]$                                      | 反復アルゴリズムで、時刻$t+1$の期待値を評価する際の定石.時刻$t$までの情報で条件づけて期待値を取り、その後で全体の期待値を取る                                |                                                                                                                                                      |
# | 射影の非拡大性: $\|\text{Proj}_{\mathcal{X}}(x) - \text{Proj}_{\mathcal{X}}(y)\| \le \|x-y\|$                          | 更新ステップの誤差評価で使う                                                                                     |                                                                                                                                                      |
# | Performance Difference Lemma                                                                                    | 2つの方策やモデルの性能差を、Occupancy measureやアドバンテージ関数で表現したい場合に使う                                              |                                                                                                                                                      |
# | Union Bound                                                                                                     | すべての状態$s$で、すべての時刻$t$でを評価したいときに使う                                                                   |                                                                                                                                                      |
# | Danskinの定理：max関数の劣勾配を特定                                                                                         | $f(x) = \max_{y \in Y} g(x,y)$ のような関数の劣勾配は、最大値を達成する $y^*$ における勾配 $\nabla_x g(x, y^*)$ で与えられる、という性質 |                                                                                                                                                      |
