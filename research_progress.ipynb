# %% [markdown]
# #### 当面の方針
# * N-PG-IGTにおけるSample complexityの証明を書いてまとめる(完)
# * Policy gradient for RMDPにおける証明を書いてまとめる(now)
# * アルゴリズムの素案を提案する(now)
#
# #### アルゴリズムの素案
# ![algo1.png](attachment:algo1.png)
# #### 懸念点
