# %% [markdown]
# ## 凸解析の基礎
# 超平面から劣勾配まで、勉強した内容をまとめています。

# %% [markdown]
# #### 分離超平面
#
# 超平面が分ける2つの空間(超平面によって定義される半空間)を考える。
# $$
# \begin{aligned}
# H^{+} & =\left\{\boldsymbol{x} \in \mathbb{R}^n \mid\langle a, x\rangle \leqq \alpha\right\} \\
# H^{-} & =\left\{\boldsymbol{x} \in \mathbb{R}^n \mid\langle a, \boldsymbol{x}\rangle \leqq \alpha\right\}
# \end{aligned}
# $$
# 半空間にそれぞれ属する集合 $S, T \subseteq \mathbb{R}^n$ が $S \subseteq H^{+}$かつ $T \subseteq H^{-}$を満たすとき，すなわち
# $$
# \begin{array}{ll}
# \langle\boldsymbol{a}, \boldsymbol{z}\rangle \leqq \alpha & (\boldsymbol{z} \in S) \\
# \langle\boldsymbol{a}, \boldsymbol{z}\rangle \leqq \alpha & (\boldsymbol{z} \in T)
# \end{array}
# $$
# 超平面は$S$、$T$を分離するといい、分離超平面と呼ばれる。
#
# **定理**
# 凸集合$S$および、その凸包に属さない点$x$について、以下の式を満たす$S$ と $x$ の分離超平面 $H=\left\{\boldsymbol{x} \in \mathbb{R}^n \mid\langle\boldsymbol{a}, \boldsymbol{x}\rangle=\alpha\right\}$が存在する。
# $$
# \langle\boldsymbol{a}, \boldsymbol{z}\rangle \geqq \alpha>\langle\boldsymbol{a}, \boldsymbol{x}\rangle \quad(\boldsymbol{z} \in S)
# $$
#
# * $z$の内積 $\geq \alpha$
# *  $x$の内積$< \alpha$
#  $S$の点（$z$）は $H$ より上
#  ↑
#  ｜   ● $z ∈ S$
#  ｜
#  ｜――――――――――――――――――― 超平面 $H$（内積 $= α$）
#  ｜
#  ｜          ● $x$（外の点）は$H$より下
#  ↓
#
# ### 支持超平面
# 凸包に属する$x$が超平面にも属している場合、それを支持超平面という。
# ****
# 凸集合 $S \subseteq \mathbb{R}^n$ が超平面 $H$ によって定義される半空間 $H^{+}$または $H^{-}$ に含まれ，さらに点 $\boldsymbol{x} \in \mathrm{cl} S$ が $H$ に含まれるとき，$H$ を $\boldsymbol{x}$ における $S$ の支持超平面（supporting hyperplane）という
#
# #### 支持超平面定理3連発
#
# **定理**
# 凸集合の境界の点はどこの点でも支持超平面を持つ。←劣勾配が存在するために凸性が必要な理由。
# ****
# 空でない凸集合 $S \subseteq \mathbb{R}^n$ は，その境界の任意の点において支持超平面をもつ．すなわち， $\boldsymbol{x} \in \operatorname{bd} S$ ならば
#
# $$
# \langle\boldsymbol{a}, \boldsymbol{z}\rangle \geqq \alpha=\langle\boldsymbol{a}, \boldsymbol{x}\rangle \quad(\boldsymbol{z} \in S)
# $$
# を満たす $a \in \mathbb{R}^n(a \neq 0)$ と $\alpha \in \mathbb{R}$ が存在する．
# ****
#
# **定理**
# 任意の凸集合と、それに属さない点に対してどの点でも凸集合と分離できる分離超平面がある。
# ****
# 任意の空でない凸集合 $S \subseteq \mathbb{R}^n$ と任意の点 $\boldsymbol{x} \notin S$ に対して，$S$ と $x$ の分離超平面が存在する．
# ****
#
# **定理**
# 凸集合同士が交わっていない場合、その凸集合同士を分離できる超平面がある。
#
# ****
# 空でない二つの凸集合 $S, T \subseteq \mathbb{R}^n$ の共通集合 $S \cap T$ が空集合 であれば，$S$ と $T$ の分離超平面が存在する．
# ****
# ### 平均値、テイラー、陰関数定理
#
# **平均値の定理**
# 関数の差分を内積で表現できる。これをつかうと、関数の勾配に関する一階条件を導出できる。
# ****
# ［平均値定理（mean value theorem）］関数 $f: \mathbb{R}^n \rightarrow \mathbb{R}$ は凸集合 $S \subseteq \mathbb{R}^n$ において微分可能とする．そのとき，任意の $\boldsymbol{x}, \boldsymbol{y} \in S$ に対して
#
# $$
# f(\boldsymbol{x})-f(\boldsymbol{y})=\langle\nabla f(\tau \boldsymbol{x}+(1-\tau) \boldsymbol{y}), \boldsymbol{x}-\boldsymbol{y}\rangle
# $$
#
#
# を満足する実数 $\tau \in(0,1)$ が存在する．
# ****
# **テイラーの定理**
# 関数の差分を内積で表現できる。2回微分可能かどうかが平均値の定理との違い
# ****
# 関数 $f: \mathbb{R}^n \rightarrow \mathbb{R}$ は凸集合 $S \subseteq \mathbb{R}^n$ において 2 回連続的微分可能とする．そのとき，任意の $\boldsymbol{x}, \boldsymbol{y} \in S$ に対して次式を満足する実数 $\tau \in(0,1)$ が存在する。
# $$
# f(\boldsymbol{x})=f(\boldsymbol{y})+\langle\nabla f(\boldsymbol{y}), \boldsymbol{x}-\boldsymbol{y}\rangle+\frac{1}{2}\left\langle\nabla^2 f(\tau \boldsymbol{x}+(1-\tau) \boldsymbol{y})(\boldsymbol{x}-\boldsymbol{y}), \boldsymbol{x}-\boldsymbol{y}\right\rangle
# $$
# ****
#
#
# **陰関数定理**
# 関数の一部の定義域をみると、そこだけ別の関数で表現できることがある。ラグランジュ、最適性条件、双対性とかにでてくる
# ****
#
# 関数 $f_i: \mathbb{R}^{n+p} \rightarrow \mathbb{R}(i=1, \ldots, n)$ が与えられており，
# ある点 $\bar{x} \in \mathbb{R}^n, \bar{u} \in \mathbb{R}^p$ において，
#
# $$
# f_i(\bar{x}, \bar{u})=0 \quad(i=1, \ldots, n)
# $$
#
#
# が成り立っているとする。
# また，各 $f_i$ は点 $(\bar{x}, \bar{u})$ のある近傍で連続的に微分可能であり，
# 次のヤコビ行列（ $\boldsymbol{x}$ に関する偏導関数からなる行列）：
#
# $$
# \nabla_x \boldsymbol{f}(\boldsymbol{x}, \boldsymbol{u})=\left[\begin{array}{ccc}
# \frac{\partial f_1}{\partial x_1} & \cdots & \frac{\partial f_n}{\partial x_1} \\
# \vdots & \ddots & \vdots \\
# \frac{\partial f_1}{\partial x_n} & \cdots & \frac{\partial f_n}{\partial x_n}
# \end{array}\right] \in \mathbb{R}^{n \times n}
# $$
#
#
# が点 $(\bar{x}, \bar{u})$ において正則（逆行列を持つ）であるとする。
#
# そのとき ：
# 点 $\bar{u}$ の適当な近傍 $U \subset \mathbb{R}^p$ において，
# 連続的微分可能な関数
#
# $$
# \phi_i: U \rightarrow \mathbb{R} \quad(i=1, \ldots, n)
# $$
#
#
# が存在して，
#
# $$
# f_i\left(\phi_1(u), \ldots, \phi_n(u), u\right)=0 \quad \text { for all } u \in U
# $$
#
#
# が成り立つ。
# また，$\phi_i(\bar{u})=\bar{x}_i$ となる。
# ****

# %% [markdown]
# ### 凸関数とその性質
#
#
#
# グラフ、エピグラフ、定義域を以下のように定義する。
#
# $$
# \text { graph } f=\left\{(\boldsymbol{x}, \beta)^{\top} \in \mathbb{R}^{n+1} \mid \beta=f(\boldsymbol{x})\right\}
# $$
# $$
# \text { epi } f=\left\{(\boldsymbol{x}, \beta)^{\top} \in \mathbb{R}^{n+1} \mid \beta \geqq f(\boldsymbol{x})\right\}
# $$
# $$
# \operatorname{dom} f=\left\{x \in \mathbb{R}^n \mid f(x)<+\infty\right\}
# $$
#
# エピグラフが凸集合になる$f$を**凸関数**という。

# %% [markdown]
# #### 強凸関数
# * $f((1-\alpha) \boldsymbol{x}+\alpha \boldsymbol{y}) \leqq(1-\alpha) f(\boldsymbol{x})+\alpha f(\boldsymbol{y})-\frac{1}{2} \sigma \alpha(1-\alpha)\|\boldsymbol{x}-\boldsymbol{y}\|^2$がすべての$\boldsymbol{x}, \boldsymbol{y} \in \operatorname{dom} f$ と $\alpha \in[0,1]$に対して成立するとそれは強凸関数らしいけどなぜ？
# 	* $\frac{1}{2} \sigma \alpha(1-\alpha)\|\boldsymbol{x}-\boldsymbol{y}\|^2$　が意味するものとは何？
# 	* 可視化して考えてみる。

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact, FloatSlider

def strongly_convex_f(x, sigma=1.0):
    return (1 + 0.5 * sigma) * x**2

def linear_upper_bound(x, x0, x1, f0, f1):
    return ((x - x0) * f1 + (x1 - x) * f0) / (x1 - x0)

def plot_strong_convexity_fixed_axes(sigma):
    x0, x1 = -1.5, 1.5
    alpha = 0.5
    x = np.linspace(-2, 2, 400)
    x_mid = (1 - alpha) * x0 + alpha * x1

    f = strongly_convex_f(x, sigma)
    f0 = strongly_convex_f(x0, sigma)
    f1 = strongly_convex_f(x1, sigma)
    f_mid = strongly_convex_f(x_mid, sigma)
    interp = linear_upper_bound(x_mid, x0, x1, f0, f1)

    fig, ax = plt.subplots(figsize=(8, 6))
    ax.plot(x, f, label=rf'strongly convex ($\sigma={sigma}$)', color='red')
    ax.plot([x0, x1], [f0, f1], 'r--', label='linear interpolation')
    ax.plot(x_mid, f_mid, 'ro', label='f(midpoint)')
    ax.plot(x_mid, interp, 'r^', label='interpolated value')
    ax.vlines(x_mid, f_mid, interp, color='purple', linestyles='dotted', label='gap')
    ax.text(x_mid + 0.1, (f_mid + interp) / 2, r'$\frac{1}{2}\sigma\alpha(1-\alpha)\|x - y\|^2$', fontsize=12, color='purple')

    ax.set_title('Strong convexity with adjustable σ')
    ax.set_xlabel('x')
    ax.set_ylabel('f(x)')
    ax.set_xlim(-2.2, 2.2)
    ax.set_ylim(-0.5, 7.5)
    ax.grid(True)
    ax.legend()
    plt.show()

interact(plot_strong_convexity_fixed_axes,
         sigma=FloatSlider(value=1.0, min=0.0, max=5.0, step=0.1, description='σ'));
# Out:
# interactive(children=(FloatSlider(value=1.0, description='σ', max=5.0), Output()), _dom_classes=('widget-inter…

# %% [markdown]
#  $\frac{1}{2} \sigma \alpha(1-\alpha)\|\boldsymbol{x}-\boldsymbol{y}\|^2$は、**任意の線形補間(グラフを横切る線分)からグラフの底までの距離**と考えればよく、強凸関数は必ずこの距離が0以上で存在している。
